# %% [markdown]
# ### Importing necessary Modules ###

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot  as  plt
import seaborn as sns
from sklearn import datasets

# %% [markdown]
# ### Loading the dataset ###

# %%
df=datasets.load_diabetes(scaled=False)
x=df.data
y=df.target
columns=df.feature_names

# %%
data=pd.DataFrame(x,columns=columns)
data
# Out:
#       age  sex   bmi      bp     s1     s2    s3    s4      s5     s6
# 0    59.0  2.0  32.1  101.00  157.0   93.2  38.0  4.00  4.8598   87.0
# 1    48.0  1.0  21.6   87.00  183.0  103.2  70.0  3.00  3.8918   69.0
# 2    72.0  2.0  30.5   93.00  156.0   93.6  41.0  4.00  4.6728   85.0
# 3    24.0  1.0  25.3   84.00  198.0  131.4  40.0  5.00  4.8903   89.0
# 4    50.0  1.0  23.0  101.00  192.0  125.4  52.0  4.00  4.2905   80.0
# ..    ...  ...   ...     ...    ...    ...   ...   ...     ...    ...
# 437  60.0  2.0  28.2  112.00  185.0  113.8  42.0  4.00  4.9836   93.0
# 438  47.0  2.0  24.9   75.00  225.0  166.0  42.0  5.00  4.4427  102.0
# 439  60.0  2.0  24.9   99.67  162.0  106.6  43.0  3.77  4.1271   95.0
# 440  36.0  1.0  30.0   95.00  201.0  125.2  42.0  4.79  5.1299   85.0
# 441  36.0  1.0  19.6   71.00  250.0  133.2  97.0  3.00  4.5951   92.0
#
# [442 rows x 10 columns]

# %%
data.head()
# Out:
#     age  sex   bmi     bp     s1     s2    s3   s4      s5    s6
# 0  59.0  2.0  32.1  101.0  157.0   93.2  38.0  4.0  4.8598  87.0
# 1  48.0  1.0  21.6   87.0  183.0  103.2  70.0  3.0  3.8918  69.0
# 2  72.0  2.0  30.5   93.0  156.0   93.6  41.0  4.0  4.6728  85.0
# 3  24.0  1.0  25.3   84.0  198.0  131.4  40.0  5.0  4.8903  89.0
# 4  50.0  1.0  23.0  101.0  192.0  125.4  52.0  4.0  4.2905  80.0

# %%
data.tail()
# Out:
#       age  sex   bmi      bp     s1     s2    s3    s4      s5     s6
# 437  60.0  2.0  28.2  112.00  185.0  113.8  42.0  4.00  4.9836   93.0
# 438  47.0  2.0  24.9   75.00  225.0  166.0  42.0  5.00  4.4427  102.0
# 439  60.0  2.0  24.9   99.67  162.0  106.6  43.0  3.77  4.1271   95.0
# 440  36.0  1.0  30.0   95.00  201.0  125.2  42.0  4.79  5.1299   85.0
# 441  36.0  1.0  19.6   71.00  250.0  133.2  97.0  3.00  4.5951   92.0

# %%
data.sample(10)
# Out:
#       age  sex   bmi     bp     s1     s2    s3   s4      s5     s6
# 118  33.0  2.0  25.4  102.0  206.0  141.0  39.0  5.0  4.8675  105.0
# 242  20.0  2.0  24.2   88.0  126.0   72.2  45.0  3.0  3.7842   74.0
# 370  54.0  1.0  21.0   78.0  188.0  107.4  70.0  3.0  3.9703   73.0
# 415  47.0  1.0  27.2   80.0  208.0  145.6  38.0  6.0  4.8040   92.0
# 173  31.0  2.0  19.0   93.0  137.0   73.0  47.0  3.0  4.4427   78.0
# 385  55.0  2.0  24.6  109.0  143.0   76.4  51.0  3.0  4.3567   88.0
# 168  49.0  2.0  31.9   94.0  234.0  155.8  34.0  7.0  5.3982  122.0
# 31   42.0  1.0  20.3   71.0  161.0   81.2  66.0  2.0  4.2341   81.0
# 89   36.0  1.0  21.9   89.0  189.0  105.2  68.0  3.0  4.3694   96.0
# 201  39.0  2.0  21.2   90.0  182.0  110.4  60.0  3.0  4.0604   98.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
data.describe()
# Out:
#               age         sex         bmi          bp          s1          s2  \
# count  442.000000  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    48.518100    1.468326   26.375792   94.647014  189.140271  115.439140
# std     13.109028    0.499561    4.418122   13.831283   34.608052   30.413081
# min     19.000000    1.000000   18.000000   62.000000   97.000000   41.600000
# 25%     38.250000    1.000000   23.200000   84.000000  164.250000   96.050000
# 50%     50.000000    1.000000   25.700000   93.000000  186.000000  113.000000
# 75%     59.000000    2.000000   29.275000  105.000000  209.750000  134.500000
# max     79.000000    2.000000   42.200000  133.000000  301.000000  242.400000
#
#                s3          s4          s5          s6
# count  442.000000  442.000000  442.000000  442.000000
# mean    49.788462    4.070249    4.641411   91.260181
# std     12.934202    1.290450    0.522391   11.496335
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Deetecting & Handling Outliers ###

# %%
sns.boxplot(data)
plt.show()

# %%
drp = data.copy()
for i in range(data.shape[1]):
    feature_data = data.iloc[:,i]
    low=np.percentile(feature_data,10)
    up=np.percentile(feature_data,90)
    drp.iloc[feature_data.index[feature_data < low],i]=low
    drp.iloc[feature_data.index[feature_data > up],i]=up

# %%
# data.clip(data.quantile(0.2),data.quantile(0.8),inplace=True,axis=1)

# %%
sns.boxplot(drp)
plt.show()

# %% [markdown]
# ### Feature Scaling ###

# %%
from sklearn.preprocessing import Normalizer,MinMaxScaler,StandardScaler,RobustScaler

# %%
# Normaliser
DX=Normalizer()
DX1=DX.fit_transform(data)
DX2=pd.DataFrame(DX1,columns=columns)
DX2
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.246898  0.008369  0.134329  0.422656  0.657000  0.390015  0.159019
# 1    0.189493  0.003948  0.085272  0.343455  0.722441  0.407409  0.276343
# 2    0.302084  0.008391  0.127966  0.390192  0.654515  0.392709  0.172020
# 3    0.088040  0.003668  0.092809  0.308139  0.726328  0.482018  0.146733
# 4    0.182625  0.003652  0.084007  0.368902  0.701279  0.458023  0.189930
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.219716  0.007324  0.103267  0.410137  0.677458  0.416728  0.153801
# 438  0.149488  0.006361  0.079197  0.238544  0.715633  0.527978  0.133585
# 439  0.239672  0.007989  0.099464  0.398136  0.647116  0.425818  0.171765
# 440  0.130298  0.003619  0.108581  0.343841  0.727496  0.453147  0.152014
# 441  0.111169  0.003088  0.060525  0.219249  0.772004  0.411324  0.299538
#
#            s4        s5        s6
# 0    0.016739  0.020337  0.364070
# ...

# %%
# Min Max Scalar
DX=MinMaxScaler()
DX1=DX.fit_transform(data)
DX2=pd.DataFrame(DX1,columns=columns)
DX2
# Out:
#           age  sex       bmi        bp        s1        s2        s3  \
# 0    0.666667  1.0  0.582645  0.549296  0.294118  0.256972  0.207792
# 1    0.483333  0.0  0.148760  0.352113  0.421569  0.306773  0.623377
# 2    0.883333  1.0  0.516529  0.436620  0.289216  0.258964  0.246753
# 3    0.083333  0.0  0.301653  0.309859  0.495098  0.447211  0.233766
# 4    0.516667  0.0  0.206612  0.549296  0.465686  0.417331  0.389610
# ..        ...  ...       ...       ...       ...       ...       ...
# 437  0.683333  1.0  0.421488  0.704225  0.431373  0.359562  0.259740
# 438  0.466667  1.0  0.285124  0.183099  0.627451  0.619522  0.259740
# 439  0.683333  1.0  0.285124  0.530563  0.318627  0.323705  0.272727
# 440  0.283333  0.0  0.495868  0.464789  0.509804  0.416335  0.259740
# 441  0.283333  0.0  0.066116  0.126761  0.750000  0.456175  0.974026
#
#            s4        s5        s6
# 0    0.282087  0.562217  0.439394
# 1    0.141044  0.222437  0.166667
# ...

# %%
# Standard scalar
DX=StandardScaler()
DX1=DX.fit_transform(data)
DX2=pd.DataFrame(DX1,columns=columns)
DX2
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.800500  1.065488  1.297088  0.459841 -0.929746 -0.732065 -0.912451
# 1   -0.039567 -0.938537 -1.082180 -0.553505 -0.177624 -0.402886  1.564414
# 2    1.793307  1.065488  0.934533 -0.119214 -0.958674 -0.718897 -0.680245
# 3   -1.872441 -0.938537 -0.243771 -0.770650  0.256292  0.525397 -0.757647
# 4    0.113172 -0.938537 -0.764944  0.459841  0.082726  0.327890  0.171178
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.876870  1.065488  0.413360  1.256040 -0.119769 -0.053957 -0.602843
# 438 -0.115937  1.065488 -0.334410 -1.422086  1.037341  1.664355 -0.602843
# 439  0.876870  1.065488 -0.334410  0.363573 -0.785107 -0.290965 -0.525441
# 440 -0.956004 -0.938537  0.821235  0.025550  0.343075  0.321306 -0.602843
# 441 -0.956004 -0.938537 -1.535374 -1.711613  1.760535  0.584649  3.654268
#
#            s4        s5        s6
# 0   -0.054499  0.418531 -0.370989
# ...

# %%
# Robust scalar
DX=RobustScaler()
DX1=DX.fit_transform(data)
DX2=pd.DataFrame(DX1,columns=columns)
DX2
# Out:
#           age  sex       bmi        bp        s1        s2        s3     s4  \
# 0    0.433735  1.0  1.053498  0.380952 -0.637363 -0.514954 -0.571429  0.000
# 1   -0.096386  0.0 -0.674897 -0.285714 -0.065934 -0.254876  1.257143 -0.500
# 2    1.060241  1.0  0.790123  0.000000 -0.659341 -0.504551 -0.400000  0.000
# 3   -1.253012  0.0 -0.065844 -0.428571  0.263736  0.478544 -0.457143  0.500
# 4    0.000000  0.0 -0.444444  0.380952  0.131868  0.322497  0.228571  0.000
# ..        ...  ...       ...       ...       ...       ...       ...    ...
# 437  0.481928  1.0  0.411523  0.904762 -0.021978  0.020806 -0.342857  0.000
# 438 -0.144578  1.0 -0.131687 -0.857143  0.857143  1.378414 -0.342857  0.500
# 439  0.481928  1.0 -0.131687  0.317619 -0.527473 -0.166450 -0.285714 -0.115
# 440 -0.674699  0.0  0.707819  0.095238  0.329670  0.317295 -0.342857  0.395
# 441 -0.674699  0.0 -1.004115 -1.047619  1.406593  0.525358  2.800000 -0.500
#
#            s5        s6
# 0    0.332755 -0.271186
# ...

# %% [markdown]
# ### Feature Selection Using Filter Method ###

# %%
from sklearn.feature_selection import mutual_info_classif,chi2,SelectKBest,mutual_info_regression
from sklearn.metrics import accuracy_score
from skfeature.function.similarity_based import fisher_score

# %%
inf=mutual_info_regression(data,y,random_state=42)
info=pd.DataFrame(inf,columns)
info.plot(kind='barh',color='pink')
plt.show()

# %%
xs=np.array(data)
inf=fisher_score.fisher_score(xs,y)
info=pd.DataFrame(inf,columns)
info.plot(kind='barh',color='pink')
plt.show()

# %%
dx=SelectKBest(chi2,k=2)
dx.fit(data,y)
indi=dx.get_support(indices=True)
data.columns[indi]
# Out:
# Index(['s1', 's2'], dtype='object')

# %% [markdown]
# ### Divide the data in training and testing set ###

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(data,y,random_state=42,test_size=0.3)

# %% [markdown]
# ### Implementing various Regression model ###

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
l=LinearRegression()
l.fit(xtrain,ytrain)
ypred=l.predict(xtest)
r2_score(ytest,ypred)
# Out:
# 0.4772897164322617

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
k=KNeighborsRegressor(n_neighbors=12)
k.fit(xtrain,ytrain)
ypred=k.predict(xtest)
r2_score(ytest,ypred)
# Out:
# 0.28206793996435675

# %%
from sklearn.svm import SVR,SVC

# %%
sv = SVC()
sv.fit(xtrain,ytrain)
ypredd=sv.predict(xtest)
r2_score(ytest,ypred)
# Out:
# 0.28206793996435675

# %%
s=SVR()
s.fit(xtrain,ytrain)
ypred=s.predict(xtest)
r2_score(ytest,ypred)
# Out:
# 0.03388459581327985

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree

# %%
d=DecisionTreeRegressor()
d.fit(xtrain,ytrain)
ypred=d.predict(xtest)
r2_score(ytest,ypred)
# Out:
# -0.08848786330592762

# %%
plot_tree(d)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
r=RandomForestRegressor()
r.fit(xtrain,ytrain)
ypred=r.predict(xtest)
r2_score(ytest,ypred)
# Out:
# 0.4645727210112871

# %% [markdown]
# ### Cross validation using Kfold and LOO  ###

# %%
from sklearn.model_selection import KFold,LeaveOneOut,cross_val_score,GridSearchCV

# %%
kf=KFold(n_splits=3)
kl=cross_val_score(l,data,y,cv=kf)
kk=cross_val_score(k,data,y,cv=kf)
ks=cross_val_score(s,data,y,cv=kf)
kd=cross_val_score(d,data,y,cv=kf)
kr=cross_val_score(r,data,y,cv=kf)
print(kl.mean(),kk.mean(),ks.mean(),kd.mean(),kr.mean())
# Out:
# 0.4887021298035316 0.29842084193169754 0.011353251905550884 -0.023590276001684174 0.437350282606448

# %%
# estimator=[]
# param_grid =[]
# g = GridSearchCV(estimator,param_grid,return_train_score=False)
# estimator.fit(xtrain,ytrain)
# ypred = g.predict(xtest)
# accuracy_score(ytest,ypred)

# %%
# lo=LeaveOneOut()
# ll=cross_val_score(l,data,y,cv=lo)
# lk=cross_val_score(k,data,y,cv=lo)
# ls=cross_val_score(s,data,y,cv=lo)
# ld=cross_val_score(d,data,y,cv=lo)
# lr=cross_val_score(r,data,y,cv=lo)
# print(ll.mean(),lk.mean(),ls.mean(),ld.mean(),lr.mean())

# %% [markdown]
# ### Wrapper method ###

# %%
from sklearn.feature_selection import RFE

# %%
rfe=RFE(l,n_features_to_select=2)
rfe.fit(xtrain,ytrain)
ypred=rfe.predict(xtest)
r2_score(ytest,ypred)
# Out:
# 0.4310712019901364

# %% [markdown]
# ### Embedded method ###

# %%
r.feature_importances_
# Out:
# array([0.05882178, 0.00932454, 0.38558186, 0.10697547, 0.0510008 ,
#        0.05123319, 0.05886568, 0.03303112, 0.1738887 , 0.07127686])

# %% [markdown]
# # KMean

# %%
from sklearn.cluster import KMeans

# %%
kma=KMeans(n_clusters=2)
kma.fit(data)
accuracy_score(ytest,kma.predict(xtest))
# Out:
# C:\Users\Kuldeep Solanki\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Kuldeep Solanki\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# 0.0

# %%
wcss=[]
for i in range(1,11):
    kma=KMeans(n_clusters=i)
    kma.fit(data)
    wcss.append(kma.inertia_)
plt.plot(range(1,11),wcss)
plt.show()
# Out:
# C:\Users\Kuldeep Solanki\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Kuldeep Solanki\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\Kuldeep Solanki\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...
